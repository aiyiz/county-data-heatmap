# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#http://www.countyhealthrankings.org/explore-health-rankings/what-and-why-we-rank/health-factors/health-behaviors/sexual-activity/teen-births

# %%
coef0 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef0C', sep='\t')
coef1 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef1C', sep='\t')
coef2 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef2C', sep='\t')
coef3 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef3C', sep='\t')
coef4 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef4C', sep='\t')
coef5 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef5C', sep='\t')
coef6 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef6C', sep='\t')
coef7 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef7C', sep='\t')
coef8 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef8C', sep='\t')
coef9 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef9C', sep='\t')
coef10 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef10C', sep='\t')
coef11 = pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\coef11C', sep='\t')

evl0=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl0C', sep='\t')
evl1=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl1C', sep='\t')
evl2=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl2C', sep='\t')
evl3=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl3C', sep='\t')
evl4=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl4C', sep='\t')
evl5=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl5C', sep='\t')
evl6=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl6C', sep='\t')
evl7=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl7C', sep='\t')
evl8=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl8C', sep='\t')
evl9=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl9C', sep='\t')
evl10=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl0C', sep='\t')
evl11=pd.read_csv('C:\\Users\\azhang\\Documents\\county health rank 2018\\evl11C', sep='\t')

# %%
#put coefficients into one table
coef=coef0.merge(coef1,on=[ 'Unnamed: 0']).merge(coef2,on=['Unnamed: 0']).merge(coef3,on=[ 'Unnamed: 0'])
coef=coef.merge(coef4,on=['Unnamed: 0']).merge(coef5,on=[ 'Unnamed: 0']).merge(coef6,on=['Unnamed: 0'])
coef=coef.merge(coef7,on=[ 'Unnamed: 0']).merge(coef8,on=['Unnamed: 0']).merge(coef9,on=['Unnamed: 0'])
coef=coef.merge(coef10,on=[ 'Unnamed: 0']).merge(coef11,on=[ 'Unnamed: 0'])

coef.index=coef['Unnamed: 0']

coef=coef.drop(columns=['Unnamed: 0' ])

coefa=coef.fillna(0)

coefa.index.name=None
coefb=round(coefa,2)
#coefb

# %%
evl=evl0.append(evl1).append(evl2).append(evl3).append(evl4).append(evl5).append(evl6).append(evl7).append(evl8).append(evl9).append(evl10).append(evl11)

evl.index=evl['Unnamed: 0']

evl=evl.drop(columns='Unnamed: 0')

evl.index.name=None

# %%
evl
# Out:
#                                         r2       mse  sample_size
# premature_age_adjusted_mortality  0.815310  0.184690       3071.0
# infant_mortality                  0.560828  0.439172       1260.0
# child_mortality                   0.518914  0.481086       1929.0
# frequent_physical_distress        0.896897  0.103103       3135.0
# frequent_mental_distress          0.893446  0.106554       3135.0
# diabetes_prevalence               0.799326  0.200674       3135.0
# HIV_prevalence                    0.546673  0.453327       2424.0
# premature_death                   0.804185  0.195815       3073.0
# poor_or_fair_health               0.897727  0.102273       3135.0
# poor_physical_health_days         0.856842  0.143158       3135.0
# premature_age_adjusted_mortality  0.815310  0.184690       3071.0
# low_birthweight                   0.652789  0.347211       3035.0

# %%
#plot coefficeints (coefficients from train and test)
fig, ax = plt.subplots(figsize=(15,25))
sns.set(rc=None) #{'axes.facecolor':'cornflowerblue', 'figure.facecolor':'cornflowerblue'})
#sns.set(font_scale=1.4)
sns.heatmap(coefb, cmap="RdBu_r", linewidths=.5, annot=True, fmt='g', center=0)
plt.show()

#PiYG
